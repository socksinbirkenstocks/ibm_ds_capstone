# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df['Date'] = pd.to_datetime(df['Date'])
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
df.head()
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-04-06   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-08-12   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22   07:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-08-10   00:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-01-03   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# 2  LEO (ISS)      NASA (COTS)         Success           No attempt
# 3  LEO (ISS)       NASA (CRS)         Success           No attempt
# 4  LEO (ISS)       NASA (CRS)         Success           No attempt

# %%
df['Launch_Site'].unique()
# Out:
# array(['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40'],
#       dtype=object)

# %%
# %%sql
# SELECT DISTINCT(Launch_Site) FROM SPACEXTBL
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
df['Launch_Site'] = df['Launch_Site'].astype(str)

# %%
# %%sql
# SELECT * FROM SPACEXTBL
# WHERE Launch_Site LIKE ('CCA%')
# LIMIT 5
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-04-06', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('2010-08-12', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('2012-05-22', '07:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('2012-08-10', '00:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('2013-01-03', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %%
df.loc[df['Launch_Site'].str.startswith('CCA')].head()
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-04-06   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-08-12   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22   07:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-08-10   00:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-01-03   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# 2  LEO (ISS)      NASA (COTS)         Success           No attempt
# 3  LEO (ISS)       NASA (CRS)         Success           No attempt
# 4  LEO (ISS)       NASA (CRS)         Success           No attempt

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %%sql
# SELECT SUM(PAYLOAD_MASS__KG_) FROM SPACEXTBL
# WHERE Customer = 'NASA (CRS)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(45596,)]

# %%
df.loc[df['Customer'] == 'NASA (CRS)']['PAYLOAD_MASS__KG_'].sum()
# Out:
# 45596

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %%sql
# SELECT AVG(PAYLOAD_MASS__KG_) FROM SPACEXTBL
# WHERE Booster_Version = 'F9 v1.1'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2928.4,)]

# %%
df.loc[df['Booster_Version'] == 'F9 v1.1']['PAYLOAD_MASS__KG_'].mean()
# Out:
# 2928.4

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# %%sql
# SELECT MIN(Date) FROM SPACEXTBL
# WHERE Landing_Outcome = 'Success (ground pad)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-12-22',)]

# %%
df['Landing_Outcome'].unique()
# Out:
# array(['Failure (parachute)', 'No attempt', 'Uncontrolled (ocean)',
#        'Controlled (ocean)', 'Failure (drone ship)',
#        'Precluded (drone ship)', 'Success (ground pad)',
#        'Success (drone ship)', 'Success', 'Failure'], dtype=object)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.loc[(df['Landing_Outcome'] == 'Success (ground pad)') ].sort_values('Date')
# Out:
#           Date Time (UTC) Booster_Version   Launch_Site  \
# 19  2015-12-22   01:29:00     F9 FT B1019   CCAFS LC-40
# 26  2016-07-18   04:45:00   F9 FT B1025.1   CCAFS LC-40
# 32  2017-01-05   11:15:00   F9 FT B1032.1    KSC LC-39A
# 29  2017-02-19   14:39:00   F9 FT B1031.1    KSC LC-39A
# 34  2017-03-06   21:07:00   F9 FT B1035.1    KSC LC-39A
# 40  2017-07-09   14:00:00   F9 B4 B1040.1    KSC LC-39A
# 38  2017-08-14   16:31:00   F9 B4 B1039.1    KSC LC-39A
# 44  2017-12-15   15:36:00  F9 FT  B1035.2  CCAFS SLC-40
# 46  2018-08-01   01:00:00   F9 B4 B1043.1  CCAFS SLC-40
#
#                                      Payload  PAYLOAD_MASS__KG_      Orbit  \
# 19  OG2 Mission 2  11 Orbcomm-OG2 satellites               2034        LEO
# 26                              SpaceX CRS-9               2257  LEO (ISS)
# 32                                   NROL-76               5300        LEO
# 29                             SpaceX CRS-10               2490  LEO (ISS)
# 34                             SpaceX CRS-11               2708  LEO (ISS)
# 40                        Boeing X-37B OTV-5               4990        LEO
# 38                             SpaceX CRS-12               3310  LEO (ISS)
# 44                             SpaceX CRS-13               2205  LEO (ISS)
# 46                                      Zuma               5000        LEO
#
#             Customer                   Mission_Outcome       Landing_Outcome
# 19           Orbcomm                           Success  Success (ground pad)
# 26        NASA (CRS)                           Success  Success (ground pad)
# 32               NRO                           Success  Success (ground pad)
# 29        NASA (CRS)                           Success  Success (ground pad)
# 34        NASA (CRS)                           Success  Success (ground pad)
# 40    U.S. Air Force                           Success  Success (ground pad)
# 38        NASA (CRS)                           Success  Success (ground pad)
# 44        NASA (CRS)                           Success  Success (ground pad)
# 46  Northrop Grumman  Success (payload status unclear)  Success (ground pad)

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %%sql
# SELECT Booster_Version FROM SPACEXTBL
# WHERE
# Landing_Outcome = 'Success (drone ship)'
# AND PAYLOAD_MASS__KG_ > 4000
# AND PAYLOAD_MASS__KG_ < 6000
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1022',), ('F9 FT B1026',), ('F9 FT  B1021.2',), ('F9 FT  B1031.2',)]

# %%
df.loc[(df['Landing_Outcome'] == 'Success (drone ship)') & (df['PAYLOAD_MASS__KG_'] > 4000) & (df['PAYLOAD_MASS__KG_'] < 6000)].sort_values('Date')
# Out:
#           Date Time (UTC) Booster_Version  Launch_Site                Payload  \
# 23  2016-06-05   05:21:00     F9 FT B1022  CCAFS LC-40               JCSAT-14
# 27  2016-08-14   05:26:00     F9 FT B1026  CCAFS LC-40               JCSAT-16
# 31  2017-03-30   22:27:00  F9 FT  B1021.2   KSC LC-39A                 SES-10
# 42  2017-11-10   22:53:00  F9 FT  B1031.2   KSC LC-39A  SES-11 / EchoStar 105
#
#     PAYLOAD_MASS__KG_ Orbit                Customer Mission_Outcome  \
# 23               4696   GTO  SKY Perfect JSAT Group         Success
# 27               4600   GTO  SKY Perfect JSAT Group         Success
# 31               5300   GTO                     SES         Success
# 42               5200   GTO            SES EchoStar         Success
#
#          Landing_Outcome
# 23  Success (drone ship)
# 27  Success (drone ship)
# 31  Success (drone ship)
# 42  Success (drone ship)

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
df['Landing_Outcome'] = df['Landing_Outcome'].astype(str)

# %%
df.loc[df['Landing_Outcome'].str.contains('Success') , 'Success_Fail'] = 1
df.loc[df['Landing_Outcome'].str.contains('Fail') , 'Success_Fail'] = 0

# %%
df['Success_Fail'].value_counts()
# Out:
# Success_Fail
# 1.0    61
# 0.0    10
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-04-06   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-08-12   15:43:00  F9 v1.0  B0004  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome  \
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
#
#    Success_Fail
# 0           0.0
# 1           0.0

# %%
df['Mission_Outcome'].unique()
# Out:
# array(['Success', 'Failure (in flight)',
#        'Success (payload status unclear)'], dtype=object)

# %%
# %%sql
# SELECT DISTINCT(Mission_Outcome) FROM SPACEXTBL
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Success',), ('Failure (in flight)',), ('Success (payload status unclear)',)]

# %%
# %%sql
# SELECT DISTINCT(Mission_Outcome), COUNT(*) FROM SPACEXTBL
# GROUP BY Mission_Outcome
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure (in flight)', 1),
#  ('Success', 99),
#  ('Success (payload status unclear)', 1)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %%sql
# SELECT DISTINCT(Booster_Version) FROM SPACEXTBL
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 v1.0  B0003',),
#  ('F9 v1.0  B0004',),
#  ('F9 v1.0  B0005',),
#  ('F9 v1.0  B0006',),
#  ('F9 v1.0  B0007',),
#  ('F9 v1.1  B1003',),
#  ('F9 v1.1',),
#  ('F9 v1.1 B1011',),
#  ('F9 v1.1 B1010',),
#  ('F9 v1.1 B1012',),
#  ('F9 v1.1 B1013',),
#  ('F9 v1.1 B1014',),
#  ('F9 v1.1 B1015',),
#  ('F9 v1.1 B1016',),
#  ('F9 v1.1 B1018',),
#  ('F9 FT B1019',),
#  ('F9 v1.1 B1017',),
#  ('F9 FT B1020',),
#  ('F9 FT B1021.1',),
#  ('F9 FT B1022',),
#  ('F9 FT B1023.1',),
#  ('F9 FT B1024',),
#  ('F9 FT B1025.1',),
#  ('F9 FT B1026',),
#  ('F9 FT B1029.1',),
#  ('F9 FT B1031.1',),
#  ('F9 FT B1030',),
#  ('F9 FT  B1021.2',),
#  ('F9 FT B1032.1',),
#  ('F9 FT B1034',),
#  ('F9 FT B1035.1',),
#  ('F9 FT  B1029.2',),
#  ('F9 FT B1036.1',),
#  ('F9 FT B1037',),
#  ('F9 B4 B1039.1',),
#  ('F9 FT B1038.1',),
#  ('F9 B4 B1040.1',),
#  ('F9 B4 B1041.1',),
#  ('F9 FT  B1031.2',),
#  ('F9 B4 B1042.1',),
#  ('F9 FT  B1035.2',),
#  ('F9 FT  B1036.2',),
#  ('F9 B4 B1043.1',),
#  ('F9 FT  B1032.2',),
#  ('F9 FT  B1038.2',),
#  ('F9 B4 B1044',),
#  ('F9 B4  B1041.2',),
#  ('F9 B4  B1039.2',),
#  ('F9 B4 B1045.1',),
#  ('F9 B5  B1046.1',),
#  ('F9 B4  B1043.2',),
#  ('F9 B4  B1040.2',),
#  ('F9 B4 B1045.2',),
#  ('F9 B5B1047.1',),
#  ('F9 B5B1048.1',),
#  ('F9 B5 B1046.2',),
#  ('F9 B5B1049.1',),
#  ('F9 B5 B1048.2',),
#  ('F9 B5 B1047.2',),
#  ('F9 B5 B1046.3',),
#  ('F9 B5B1050',),
#  ('F9 B5B1054',),
#  ('F9 B5 B1049.2',),
#  ('F9 B5 B1048.3',),
#  ('F9 B5B1051.1',),
#  ('F9 B5B1056.1',),
#  ('F9 B5 B1049.3',),
#  ('F9 B5 B1051.2',),
#  ('F9 B5 B1056.2',),
#  ('F9 B5 B1047.3',),
#  ('F9 B5 B1048.4',),
#  ('F9 B5B1059.1',),
#  ('F9 B5 B1056.3',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1046.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1059.2',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5B1058.1',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1059.3',),
#  ('F9 B5B1060.1',),
#  ('F9 B5 B1058.2',),
#  ('F9 B5 B1051.5',),
#  ('F9 B5 B1049.6',),
#  ('F9 B5 B1059.4',),
#  ('F9 B5 B1060.2',),
#  ('F9 B5 B1058.3',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5B1062.1',),
#  ('F9 B5B1061.1',),
#  ('F9 B5B1063.1',),
#  ('F9 B5 B1049.7',),
#  ('F9 B5 B1058.4',)]

# %%
# %%sql
# SELECT DISTINCT(Booster_Version) FROM SPACEXTBL
# WHERE PAYLOAD_MASS__KG_ = (SELECT MAX(PAYLOAD_MASS__KG_) FROM SPACEXTBL)
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2',),
#  ('F9 B5 B1058.3',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7',)]

# %%
df.loc[df['PAYLOAD_MASS__KG_'] == df['PAYLOAD_MASS__KG_'].max(), 'Booster_Version'].unique()
# Out:
# array(['F9 B5 B1048.4', 'F9 B5 B1049.4', 'F9 B5 B1051.3', 'F9 B5 B1056.4',
#        'F9 B5 B1048.5', 'F9 B5 B1051.4', 'F9 B5 B1049.5',
#        'F9 B5 B1060.2 ', 'F9 B5 B1058.3 ', 'F9 B5 B1051.6',
#        'F9 B5 B1060.3', 'F9 B5 B1049.7 '], dtype=object)

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 4, 2) as month to get the months and substr(Date,7,4)='2015' for year.**

# %%
# %%sql
# Select
# CASE SUBSTRING(Date, 6, 2)
#                 WHEN '01' THEN 'January'
#                 WHEN '02' THEN 'February'
#                 WHEN '03' THEN 'March'
#                 WHEN '04' THEN 'April'
#                 WHEN '05' THEN 'May'
#                 WHEN '06' THEN 'June'
#                 WHEN '07' THEN 'July'
#                 WHEN '08' THEN 'August'
#                 WHEN '09' THEN 'September'
#                 WHEN '10' THEN 'October'
#                 WHEN '11' THEN 'November'
#                 WHEN '12' THEN 'December'
#             END AS Month_Name
#  FROM SPACEXTBL
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('April',),
#  ('August',),
#  ('May',),
#  ('August',),
#  ('January',),
#  ('September',),
#  ('March',),
#  ('June',),
#  ('April',),
#  ('July',),
#  ('May',),
#  ('July',),
#  ('September',),
#  ('October',),
#  ('November',),
#  ('February',),
#  ('April',),
#  ('April',),
#  ('June',),
#  ('December',),
#  ('January',),
#  ('April',),
#  ('August',),
#  ('June',),
#  ('May',),
#  ('June',),
#  ('July',),
#  ('August',),
#  ('January',),
#  ('February',),
#  ('March',),
#  ('March',),
#  ('January',),
#  ('May',),
#  ('March',),
#  ('June',),
#  ('June',),
#  ('May',),
#  ('August',),
#  ('August',),
#  ('July',),
#  ('September',),
#  ('November',),
#  ('October',),
#  ('December',),
#  ('December',),
#  ('August',),
#  ('January',),
#  ('February',),
#  ('June',),
#  ('March',),
#  ('February',),
#  ('April',),
#  ('November',),
#  ('May',),
#  ('April',),
#  ('June',),
#  ('July',),
#  ('July',),
#  ('July',),
#  ('October',),
#  ('August',),
#  ('November',),
#  ('March',),
#  ('May',),
#  ('December',),
#  ('November',),
#  ('February',),
#  ('February',),
#  ('April',),
#  ('May',),
#  ('December',),
#  ('July',),
#  ('June',),
#  ('November',),
#  ('May',),
#  ('December',),
#  ('July',),
#  ('January',),
#  ('January',),
#  ('February',),
#  ('July',),
#  ('March',),
#  ('April',),
#  ('May',),
#  ('April',),
#  ('June',),
#  ('June',),
#  ('July',),
#  ('July',),
#  ('August',),
#  ('August',),
#  ('March',),
#  ('June',),
#  ('October',),
#  ('October',),
#  ('May',),
#  ('November',),
#  ('November',),
#  ('November',),
#  ('June',)]

# %%
# %%sql
# SELECT
# CASE SUBSTRING(Date, 6, 2)
#                 WHEN '01' THEN 'January'
#                 WHEN '02' THEN 'February'
#                 WHEN '03' THEN 'March'
#                 WHEN '04' THEN 'April'
#                 WHEN '05' THEN 'May'
#                 WHEN '06' THEN 'June'
#                 WHEN '07' THEN 'July'
#                 WHEN '08' THEN 'August'
#                 WHEN '09' THEN 'September'
#                 WHEN '10' THEN 'October'
#                 WHEN '11' THEN 'November'
#                 WHEN '12' THEN 'December'
#             END AS Month_Name,
# Landing_Outcome,
# Booster_Version,
# Launch_Site
# FROM SPACEXTBL
# WHERE
# Landing_Outcome = 'Failure (drone ship)'
# AND Date LIKE '2015%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('October', 'Failure (drone ship)', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('April', 'Failure (drone ship)', 'F9 v1.1 B1015', 'CCAFS LC-40')]

# %%
df.head(2)
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-04-06   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-08-12   15:43:00  F9 v1.0  B0004  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome  \
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
#
#    Success_Fail
# 0           0.0
# 1           0.0

# %%
df['Landing_Outcome'].unique()
# Out:
# array(['Failure (parachute)', 'No attempt', 'Uncontrolled (ocean)',
#        'Controlled (ocean)', 'Failure (drone ship)',
#        'Precluded (drone ship)', 'Success (ground pad)',
#        'Success (drone ship)', 'Success', 'Failure'], dtype=object)

# %%
df.loc[(df['Landing_Outcome'] == 'Failure (drone ship)') & (df['Date'].dt.year == 2015), ['Booster_Version', 'Launch_Site', 'Date']]
# Out:
#    Booster_Version  Launch_Site       Date
# 13   F9 v1.1 B1012  CCAFS LC-40 2015-10-01
# 16   F9 v1.1 B1015  CCAFS LC-40 2015-04-14

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
# %%sql
# SELECT
#     Landing_Outcome,
#     COUNT(*) AS Outcome_Count,
#     RANK() OVER (ORDER BY COUNT(*) DESC) AS Outcome_Rank
# FROM
#     SPACEXTBL
# WHERE
#     Date BETWEEN '2010-06-04' AND '2017-03-20'
#
# GROUP BY
#     Landing_Outcome
# ORDER BY
#     Outcome_Count DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('No attempt', 10, 1),
#  ('Success (ground pad)', 5, 2),
#  ('Success (drone ship)', 5, 2),
#  ('Failure (drone ship)', 5, 2),
#  ('Controlled (ocean)', 3, 5),
#  ('Uncontrolled (ocean)', 2, 6),
#  ('Precluded (drone ship)', 1, 7),
#  ('Failure (parachute)', 1, 7)]

# %%
sub_df = df.loc[(df['Date'] > '2010-06-04') & (df['Date'] < '2017-03-20')]

# %%
sub_df.groupby('Landing_Outcome').count().sort_values(by='Date', ascending=False)
# Out:
#                         Date  Time (UTC)  Booster_Version  Launch_Site  \
# Landing_Outcome
# No attempt                10          10               10           10
# Failure (drone ship)       5           5                5            5
# Success (drone ship)       5           5                5            5
# Success (ground pad)       5           5                5            5
# Controlled (ocean)         3           3                3            3
# Uncontrolled (ocean)       2           2                2            2
# Failure (parachute)        1           1                1            1
# Precluded (drone ship)     1           1                1            1
#
#                         Payload  PAYLOAD_MASS__KG_  Orbit  Customer  \
# Landing_Outcome
# No attempt                   10                 10     10        10
# Failure (drone ship)          5                  5      5         5
# Success (drone ship)          5                  5      5         5
# Success (ground pad)          5                  5      5         5
# Controlled (ocean)            3                  3      3         3
# Uncontrolled (ocean)          2                  2      2         2
# Failure (parachute)           1                  1      1         1
# Precluded (drone ship)        1                  1      1         1
#
#                         Mission_Outcome  Success_Fail
# Landing_Outcome
# No attempt                           10             0
# Failure (drone ship)                  5             5
# Success (drone ship)                  5             5
# Success (ground pad)                  5             5
# Controlled (ocean)                    3             0
# Uncontrolled (ocean)                  2             0
# Failure (parachute)                   1             1
# Precluded (drone ship)                1             0

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
